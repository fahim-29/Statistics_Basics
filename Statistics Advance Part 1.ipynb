# %% [markdown]
# # Name         : Fahim Ahmad
# # Assignment   : Statistics Advance Part 1
# # Date         : July, 04, 2025

# %% [markdown]
# #### Q.1 What is a random variable in probability theory

# %% [markdown]
# - A **random variable** is a numerical quantity whose value is determined by the outcome of a random experiment.
# - for Example
# Let’s say we toss a fair coin 3 times.
#
# The random experiment: Tossing the coin 3 times.
#
# The random variable X = number of heads.
#
# Possible outcomes and values of
# 𝑋
# X:
#
# TTT → X = 0
#
# HTT, THT, TTH → X = 1
#
# HHT, HTH, THH → X = 2
#
# HHH → X = 3
#
# So here,
# 𝑋
# X is a discrete random variable that can take values 0, 1, 2, or 3.

# %% [markdown]
# #### Q.2 What are the types of random variables?

# %% [markdown]
# - A discrete random variable takes countable values — usually whole numbers.
#
# - **Example** 1: Rolling a Die
# Let
# 𝑋
# X = the number rolled on a fair 6-sided die.
#
# - P(x)= {1,2,3,4,5,6}
#
# - You can list all outcomes.
#
# - **Example** 2: Number of Emails Received in a Day
#
# - 2. Continuous Random Variable
# A continuous random variable takes infinite, uncountable values over a range — typically real numbers.
#
# - **Example** 1: Height of Students
# Let
# 𝐻
# H = height of a student (in cm)
#
# - Possible values: any real number in a range (e.g., 150.1 cm, 150.11 cm, 150.111 cm, ...)
#
# - **Example** 2: Temperature Throughout the Day
# Let
# 𝑇
# T = temperature at noon
#
# - It can be any value like 23.4°C, 23.401°C, etc.

# %% [markdown]
# #### Q.3 What is the difference between discrete and continuous distributions?

# %% [markdown]
#  **Discrete Distribution:**
# Deals with discrete random variables (countable values).
#
# Takes values like 0, 1, 2, 3, etc. — no decimals between them.
#
# Uses a Probability Mass Function (PMF) to assign probabilities.
#
# Can assign a positive probability to a specific value (e.g., P(X = 2) = 0.3).
#
# The total sum of all probabilities is always 1.
#
# Represented visually using bar graphs.
#
# Example: Number of goals scored in a soccer match.
#
# **Continuous Distribution:**
# Deals with continuous random variables (uncountably infinite values).
#
# Takes any value within an interval (e.g., 2.35, 2.351, 2.3517, etc.).
#
# Uses a Probability Density Function (PDF) to describe probabilities.
#
# The probability of any exact value is always 0 (e.g., P(X = 2.5) = 0).
#
# Probability is found by calculating the area under the curve over an interval.
#
# The total area under the curve is always 1.
#
# Represented visually using smooth curves.
#
# Example: Time taken to complete a task or height of individuals.

# %% [markdown]
# #### Q.4 What are probability distribution functions (PDF)?

# %% [markdown]
# - Probability Distribution Function is a general concept that refers to any function that describes the distribution of probabilities across the possible values of a random variable — whether it's discrete or continuous.Therefore
#
# - For discrete random variables, the probability distribution function is the Probability Mass Function (PMF).
# - For continuous random variables, it is the Probability Density Function (PDF).

# %% [markdown]
# #### Q.5 How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?

# %% [markdown]
# - The Cumulative Distribution Function (CDF) gives you the probability that a random variable is less than or equal to a certain value. In other words, it adds up (accumulates) all the probabilities up to that point. So if you're looking at
# - On the other hand, the Probability Distribution Function (PDF) — which is a general term — represents how the probabilities are spread across values of the random variable. If the variable is discrete, we use the Probability Mass Function (PMF), which gives the exact probability of specific values. If the variable is continuous, we use the Probability Density Function (PDF), which gives probability density, not exact probabilities. So, the CDF is about the total probability accumulated up to a point, while the PDF or PMF is about the individual probability (or density) at a point.
#
# - Also, the value of the CDF always goes from 0 to 1, since it’s adding up total probability. The PDF or PMF may go up or down depending on how likely individual values are — but the total area (PDF) or total sum (PMF) across all values is still 1.

# %% [markdown]
# #### Q.6 What is a discrete uniform distribution

# %% [markdown]
# - A discrete uniform distribution is a probability distribution where each possible outcome has an equal and constant probability of occurring.
# - it models situations where all outcomes are equally likely.
#
# - Example: Rolling a Fair Die
# - If you roll a fair 6-sided die, each outcome — 1, 2, 3, 4, 5, and 6 — has the same probability of:
#
# - 𝑃(𝑋=𝑥)= 1/6
# - for 𝑥 = {1,2,3,4,5,6}

# %% [markdown]
# #### Q.7 What are the key properties of a Bernoulli distribution?

# %% [markdown]
# - **The Bernoulli distribution** is a discrete probability distribution that models a single trial with only two possible outcomes:
# - Success (usually coded as 1)
# - Failure (usually coded as 0)
# - **Binary Outcome:**
# - The random variable takes on only two values — typically 1 (success) and 0 (failure).
# - Example: Tossing a coin — outcome is either heads (1) or tails (0).
# - Single Trial:
# - It represents the probability distribution of one single experiment or trial.
#
# - **One Parameter (p):**
# - The distribution is fully described by one parameter,
# - p, which is the probability of success (1).
#
# - P(X=1)=p, and
# - P(X=0)=1−p.
# - **Mean (Expected Value):**
# - The expected value (mean) of a Bernoulli distribution is simply
# - E[X]=p.
# - Variance:
# - The variance is given by
# - Var(X)=p(1−p).

# %% [markdown]
# #### Q.8 What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# - The Binomial distribution models the total number of successes in multiple independent Bernoulli trials. So, if you repeat a Bernoulli trial n times, and you want to know how many times you get success (like heads), you use a Binomial distribution.
#
# - **Real-World Examples:**
# - Tossing a coin: What’s the probability of getting 4 heads in 6 tosses?
# - Quality control: A factory finds that 5% of products are defective. What’s the chance that exactly 2 out of 10 sampled products are defective?

# %% [markdown]
# #### Q.9 What is the Poisson distribution and where is it applied?

# %% [markdown]
# - The Poisson distribution is a probability mass function (PMF) that models the number of events happening in a fixed interval of time or space — when those events happen independently and at a constant average rate.
# - **Customer Service**
# - Number of customers arriving at a restaurant or call center per hour.
#
# - **Healthcare**
# - Number of patients arriving at the emergency room per night.
#
# - **Manufacturing/Quality Control**
# - Number of defects in a certain length of wire or roll of fabric.
# - **Traffic/Transportation**
# - Number of cars passing through a toll booth per minute.

# %% [markdown]
# #### Q.10 What is a continuous uniform distribution?

# %% [markdown]
# - The Continuous Uniform Distribution models situations where all values within a given range are equally likely to occur. It applies to continuous random variables, meaning the outcomes can take any real value within a specified interval.
# - **Example**
# - Let's Say a bus arrives randomly anytime between 10:00 AM and 10:30 AM (so, a = 0 minutes, b = 30 minutes). If you arrive at a random time during this interval, the probability that the bus comes within the next 5 minutes is:
# - P(0≤X≤5)= 5/30 = 1/6
# - Every 5-minute interval has equal likelihood under the continuous uniform distribution.

# %% [markdown]
# #### Q.11 What are the characteristics of a normal distribution?

# %% [markdown]
# - Bell-Shaped Curve: The graph of a normal distribution is symmetric and shaped like a bell.
#
# - Symmetry Around the Mean: The distribution is perfectly symmetric about the mean. This means the left side mirrors the right side.
#
# - Mean = Median = Mode: All three measures of central tendency are equal and located at the center of the distribution.
# - Empirical Rule (68–95–99.7 Rule):
#
# - ~68% of the data falls within ±1 standard deviation from the mean
# - 95% falls within ±2 standard deviations
# - ~99.7% falls within ±3 standard deviations
# - Total Area Under the Curve = 1:
# - The entire probability under the curve sums up to 1 (or 100%).
# - Skewness is 0:
# - Since it’s symmetric, the skewness (measure of asymmetry) is exactly zero.

# %% [markdown]
# #### Q.12  What is the standard normal distribution, and why is it important

# %% [markdown]
# - The standard normal distribution is a special case of the normal distribution where:
# - Mean (μ) = 0
# - Standard deviation (σ) = 1
# - It's a bell-shaped, symmetric curve centered at 0.
# - The formula for converting any normal distribution to a standard normal distribution is:
#
# - 𝑧  = (𝑥 − 𝜇) /𝜎
# - This converts your data point 𝑥
# - x into a z-score, which tells you how many standard deviations it is from the mean.

# %% [markdown]
# #### Q.13 What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# - The Central Limit Theorem (CLT) states that:
# - When we take many random samples of a sufficiently large size (usually n ≥ 30) from a population with mean μ and standard deviation σ, then the distribution of the sample means will approximate a normal distribution, regardless of the shape of the original population distribution (whether it’s skewed, binomial, Poisson, etc.).
#
# - It allows us to use the normal distribution:
# - Even if the original data is skewed, bimodal, or non-normal, we can still use normal-based methods when working with sample means.
# - Foundation for inferential statistics:
# - CLT is the backbone of many statistical techniques like:
# - Confidence intervals
# - Hypothesis testing
# - Z-tests and t-tests
# - It simplifies complex problems:
# - It turns unknown or complex distributions into something predictable and manageable—the normal distribution.

# %% [markdown]
# #### Q.14 How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# - The normal distribution is the familiar bell curve used in many statistical methods (confidence intervals, hypothesis tests, etc.).
# - The CLT justifies this by saying:
# - If you take many random samples from any population (regardless of its shape), and the sample size is large enough (usually ≥ 30), then the distribution of the sample means will become approximately normal.

# %% [markdown]
# #### Q.15 What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# - The Z-statistic (or Z-score) is used in hypothesis testing when we want to determine whether a sample mean is significantly different from a known population mean — especially when the population standard deviation is known and the sample size is large (typically

# %% [markdown]
# #### Q.16 How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# - The Z-score tells you how many standard deviations a value is away from the mean.
# - A positive z-score means the value is above the mean, and a negative z-score means it's below the mean.
# - You can use Z-tables to find the probability (or area under the curve) to the left of that Z-value on a standard normal distribution.
#
# - It standardizes data, making it easier to compare values from different distributions.
# - It helps in hypothesis testing, confidence intervals, and detecting outliers.
# - It's essential in the standard normal distribution (mean 0, standard deviation 1).

# %% [markdown]
# #### Q.17 What are point estimates and interval estimates in statistics?

# %% [markdown]
# - A point estimate is a single value used to estimate an unknown population parameter.
# - An interval estimate gives a range of values within which the population parameter is likely to fall, with a certain level of confidence (like 95%).

# %% [markdown]
# #### Q.18 What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# - A confidence interval tells us how precise our point estimate is. They are extremely important in statistical analysis because they give us more than just a single estimate—they provide a range of plausible values for an unknown population parameter and express the uncertainty in our estimate
# - A narrow interval = more precise estimate
# - A wide interval = more uncertainty in the estimate
# - Example:
# - If the mean income is estimated to be $50,000 with a 95% CI of ($49,000, $51,000), that’s more precise than ($45,000, $55,000).

# %% [markdown]
# #### Q. 19 What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# - The Z-score and confidence interval are closely related in inferential statistics—specifically when estimating population parameters (like the mean) and quantifying how confident we are in those estimates.
# -  Z-score determines the width of the confidence interval
# - The Z-score (also called the critical value) tells us how many standard deviations we must go from the mean to capture a certain percentage of the data.
# - For example:
# - Z = 1.96 gives a 95% confidence interval
# - Z = 1.64 gives a 90% confidence interval
# - Z = 2.58 gives a 99% confidence interval
# - Formula for a Confidence Interval using Z-score (for population mean):
# - **CI= x ± Z⋅ ( n/σ )**

# %% [markdown]
# #### Q.20 How are Z-scores used to compare different distributions?

# %% [markdown]
# - Z-scores are incredibly useful when you want to compare values from different distributions, especially when those distributions have different means and standard deviations.
# - A Z-score standardizes values by converting them into a common scale—that is, how many standard deviations a data point is from the mean.
# - **Example**
# - Two students, A and B, took exams in different subjects — Student A in Science and Student B in Arts. Their exams had different scoring systems and different levels of difficulty, so comparing their raw scores directly wouldn’t be fair.
# - To make a fair comparison, we calculate the Z-score for each student:
# - **Z = (X - μ) / σ**
# - Where:
# X is the student’s score
#
# μ is the class average (mean)
#
# σ is the standard deviation of scores in that class
#
# By converting their raw scores into Z-scores, we standardize the results — putting both students on the same scale with mean = 0 and standard deviation = 1.
#
# Now, the Z-score tells us how many standard deviations each student is from their class average. If:
#
# Student A has a Z-score of 1.5
#
# Student B has a Z-score of 2.6
#
# Then, even though their raw scores came from different subjects and exams, we can say Student B performed better relative to their class because their Z-score is higher.
#
# This is how Z-scores help in comparing performance across different distributions fairly.

# %% [markdown]
# #### Q.21 What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# - **Random Sampling:**
# - The samples must be drawn randomly from the population.
# - **Independence:**
# - Each sample must be independent of the others — the outcome of one should not influence another.
# - **Sample Size:**
# - If the population is normal, small samples (even < 30) are fine.
# - If the population is not normal, a sample size of at least 30 is generally recommended to ensure the sample means approximate a normal distribution.
# - **Finite Variance:**
# - The population from which the samples are drawn must have a finite variance (i.e., no infinite or undefined spread of data).
# - **Identically Distributed:**
# - Each sample is drawn from the same population distribution.

# %% [markdown]
# #### Q.22  What is the concept of expected value in a probability distribution?

# %% [markdown]
# - The expected value (also known as the mean) of a probability distribution gives you the long-run average outcome of a random variable after many trials or repetitions of an experiment.

# %% [markdown]
# #### Q.23 How does a probability distribution relate to the expected outcome of a random variable?

# %% [markdown]
# - The probability distribution of a random variable tells us how likely each possible outcome is. The expected outcome (also called the expected value) is a weighted average of all these possible outcomes, weighted by their probabilities.
# - The expected value is calculated directly from the probability distribution.
# - The probability distribution describes how likely each value is.
# - The expected value uses those probabilities to find the long-term average outcome.
# - So, probability distribution → expected value.
# - **for example**
# - If you repeated a random experiment many times, the average result you’d get in the long run is the expected value, and you calculate it using the probabilities from the distribution.

# %% [markdown]
# #### Q.1 Write a Python program to generate a random variable and display its value.

# %%
import numpy as np


random_sample = np.random.random()
print(random_sample)
# Out:
# 0.6180921379693409

# %% [markdown]
# #### Q.2 Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
'''Probability Mass Function (PMF) for discrete data, using a classic example: rolling a fair six-sided die.'''

import matplotlib.pyplot as plt

# Discrete outcomes for a fair die
outcomes = [1, 2, 3, 4, 5, 6]

# PMF for a fair die: each outcome has a probability of 1/6
probabilities = [1/6] * 6

# Plotting the PMF
plt.figure(figsize=(8, 5))
plt.stem(outcomes, probabilities, basefmt=" ", use_line_collection=True)
plt.title("PMF of a Fair 6-Sided Die (Discrete Uniform Distribution)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.ylim(0, 0.25)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(outcomes)
plt.show()
# Out:
# /var/folders/t4/1v9zfkcn48vg1jq5w883srmw0000gn/T/ipykernel_31958/1484986641.py:13: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(outcomes, probabilities, basefmt=" ", use_line_collection=True)

# %% [markdown]
# #### Q.3 Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
    x (int): The outcome (should be 0 or 1)
    p (float): The probability of success (0 ≤ p ≤ 1)

    Returns:
    float: The probability P(X = x)
    """
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        return 0  # Bernoulli distribution only defined for x = 0 or 1


print("P(X = 0):", bernoulli_pdf(0, 0.7))
print("P(X = 1):", bernoulli_pdf(1, 0.7))
print("P(X = 2):", bernoulli_pdf(2, 0.7))
# Out:
# P(X = 0): 0.30000000000000004
# P(X = 1): 0.7
# P(X = 2): 0

# %% [markdown]
# #### Q.4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt


n = 10
p = 0.5     
size = 1000


data = np.random.binomial(n, p, size)

plt.figure(figsize=(8, 5))
plt.hist(data, bins=range(n+2), align='left', rwidth=0.8, color='green')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### Q.5 Create a Poisson distribution and visualize it using Python

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson


mu = 4  
x = np.arange(0, 15)  


pmf_values = poisson.pmf(x, mu)


plt.figure(figsize=(8, 5))
plt.bar(x, pmf_values, color='blue', alpha=0.7)
plt.title(f'Poisson Distribution (λ = {mu})')
plt.xlabel('Number of Events (k)')
plt.ylabel('Probability P(X = k)')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(x)
plt.show()

# %% [markdown]
# #### Q.6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt


outcomes = np.arange(1, 7)
probability = 1 / len(outcomes)


cdf = np.cumsum([probability] * len(outcomes))

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(outcomes, cdf, where='post', color='royalblue', label='CDF')
plt.scatter(outcomes, cdf, color='red', zorder=5)
plt.title("CDF of a Discrete Uniform Distribution (Fair Die)")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(outcomes)
plt.ylim(0, 1.1)
plt.legend()
plt.show()

# %% [markdown]
# #### Q.7 Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

'''Generate 1000 samples from a continuous uniform distribution between 0 and 1 '''
samples = np.random.uniform(0, 1, 1000)

# Plot the histogram of the samples
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=50, density=True, alpha=0.6,  edgecolor='black', label='Histogram')


x = np.linspace(0, 1, 1000)
pdf = uniform.pdf(x, loc=0, scale=1)
plt.plot(x, pdf, 'r-', lw=2, label='PDF')


plt.title('Continuous Uniform Distribution U(0,1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# #### Q.8  Simulate data from a normal distribution and plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt


mean = 0       
std_dev = 1    
size = 1000   


samples = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot the histogram
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Histogram')


from scipy.stats import norm
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
pdf = norm.pdf(x, mean, std_dev)
plt.plot(x, pdf, 'r-', lw=2, label='Normal PDF')


plt.title('Normal Distribution (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# #### Q.9 Write a Python function to calculate Z-scores from a dataset and plot them

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std_dev

    # Plot Z-scores (line plot and histogram)
    plt.figure(figsize=(14, 5))

    # Line plot
    plt.subplot(1, 2, 1)
    plt.plot(z_scores, marker='o', linestyle='-', color='blue')
    plt.axhline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.title('Z-Scores (Line Plot)')
    plt.xlabel('Index')
    plt.ylabel('Z-Score')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # Histogram
    plt.subplot(1, 2, 2)
    plt.hist(z_scores, bins=10, color='skyblue', edgecolor='black')
    plt.title('Z-Scores (Histogram)')
    plt.xlabel('Z-Score')
    plt.ylabel('Frequency')
    plt.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()

    return z_scores


sample_data = np.random.normal(loc=50, scale=10, size=100)
z_scores = calculate_and_plot_z_scores(sample_data)

# %% [markdown]
# #### Q.10 Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

def demonstrate_clt(sample_size=30, num_samples=1000):
    '''Step 1: Generate non-normal population data (exponential distribution)'''
    population = np.random.exponential(scale=2.0, size=100000)

    ''' Step 2: Draw multiple samples and compute sample means'''
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size)
        sample_means.append(np.mean(sample))


    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.hist(population, bins=50, color='skyblue', edgecolor='black', density=True)
    plt.title('Original Population (Exponential)')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.5)

    # Step 4: Plot the distribution of sample means
    plt.subplot(1, 2, 2)
    plt.hist(sample_means, bins=30, color='orange', edgecolor='black', density=True)
    plt.title(f'Distribution of Sample Means\n(sample size = {sample_size}, n = {num_samples})')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()


demonstrate_clt(sample_size=50, num_samples=1000)

# %% [markdown]
# #### Q.11 Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

def clt_from_normal_distribution(pop_mean=100, pop_std=15, sample_size=30, num_samples=1000):
    ''' Step 1: Generate a population that follows a normal distribution'''
    population = np.random.normal(loc=pop_mean, scale=pop_std, size=100000)

    ''' Step 2: Draw multiple samples and compute their means'''
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=False)
        sample_means.append(np.mean(sample))


    plt.figure(figsize=(14, 6))


    plt.subplot(1, 2, 1)
    plt.hist(population, bins=30, color='skyblue', edgecolor='black', density=True, )
    plt.title('Original Normal Population')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.5)


    plt.subplot(1, 2, 2)
    plt.hist(sample_means, bins=20, color='lightgreen', edgecolor='black', density=True)
    plt.title(f'Distribution of Sample Means\n(sample size = {sample_size}, n = {num_samples})')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()


clt_from_normal_distribution(sample_size=50, num_samples=1000)

# %% [markdown]
# #### Q.12 Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    
    x = np.linspace(-4, 4, 1000)
    

    y = norm.pdf(x, loc=0, scale=1)  


    plt.figure(figsize=(10, 5))
    plt.plot(x, y, color='blue', lw=2, label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (mean = 0, std = 1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.axvline(0, color='black', linestyle='--', linewidth=1)
    plt.legend()
    plt.show()


plot_standard_normal_distribution()

# %% [markdown]
# #### Q.13 Generate random variables and calculate their corresponding probabilities using the binomial distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom


n = 10       
p = 0.5      


binomial_samples = np.random.binomial(n, p, 1000)


x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)


print("Sample binomial outcomes:", binomial_samples[:10])


for i in range(len(x)):
    print(f"P(X = {x[i]}) = {pmf_values[i]:.4f}")

# Plot the PMF
plt.figure(figsize=(8, 5))
plt.stem(x, pmf_values, basefmt=" ", use_line_collection=True)
plt.title("Binomial Distribution PMF (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Sample binomial outcomes: [4 4 8 5 6 7 7 4 6 5]
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010
# /var/folders/t4/1v9zfkcn48vg1jq5w883srmw0000gn/T/ipykernel_31958/688375408.py:25: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, pmf_values, basefmt=" ", use_line_collection=True)

# %% [markdown]
# #### Q.14 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mu, sigma):
    """Calculate the Z-score for a given data point."""
    return (x - mu) / sigma

def plot_standard_normal_with_z(x, mu, sigma):
    """Plot standard normal distribution and mark the Z-score."""
    z = calculate_z_score(x, mu, sigma)
    
    # Generate x values for the standard normal curve
    x_vals = np.linspace(-4, 4, 1000)
    y_vals = norm.pdf(x_vals, 0, 1)

    plt.figure(figsize=(10, 5))
    plt.plot(x_vals, y_vals, label="Standard Normal Distribution", color="blue")
    plt.axvline(z, color='red', linestyle='--', label=f"Z-score = {z:.2f}")
    plt.fill_between(x_vals, y_vals, where=(x_vals <= z), color='red', alpha=0.2)
    
    plt.title("Z-score Compared to Standard Normal Distribution")
    plt.xlabel("Z-value")
    plt.ylabel("Probability Density")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.show()
    
    print(f"Z-score for x = {x} (mean = {mu}, std = {sigma}): {z:.2f}")


calculate_z_score(75,70,5)
plot_standard_normal_with_z(75,70,5)
# Out:
# Z-score for x = 75 (mean = 70, std = 5): 1.00

# %% [markdown]
# #### Q.15 Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):

    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    
    # Standard error
    standard_error = population_std / np.sqrt(sample_size)
    
    # Z-statistic
    z = (sample_mean - population_mean) / standard_error
    
    # Critical Z-value for two-tailed test
    z_critical = norm.ppf(1 - alpha / 2)
    

    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"Z-statistic = {z:.2f}")
    print(f"Critical Z-value = ±{z_critical:.2f}")
    

    if abs(z) > z_critical:
        print("Reject the null hypothesis (significant difference).")
    else:
        print("Fail to reject the null hypothesis (no significant difference).")


sample = [172, 174, 169, 171, 173, 175, 170, 168, 176, 169]


z_test(sample_data=sample, population_mean=170, population_std=3)
# Out:
# Sample Mean = 171.70
# Z-statistic = 1.79
# Critical Z-value = ±1.96
# Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# #### Q.16 Create a confidence interval for a dataset using Python and interpret the result

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)  # standard error
    t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_critical * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    print(f"Sample Mean = {mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval = ({lower_bound:.2f}, {upper_bound:.2f})")

    return (lower_bound, upper_bound)


data = [45, 47, 49, 46, 48, 47, 50, 49, 46, 48]


confidence_interval(data)
# Out:
# Sample Mean = 47.50
# 95% Confidence Interval = (46.37, 48.63)
# (46.368921418629505, 48.631078581370495)

# %% [markdown]
# #### Q.17 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt


np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=50)  # mean=100, std=15, n=50


sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
n = len(data)

'''Calculate standard error and margin of error'''
confidence = 0.95
alpha = 1 - confidence
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
standard_error = sample_std / np.sqrt(n)
margin_of_error = t_critical * standard_error


ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error


print(f"Sample Mean: {sample_mean:.2f}")
print(f"{int(confidence * 100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")


plt.hist(data, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(sample_mean, color='red', linestyle='--', label='Sample Mean')
plt.axvline(ci_lower, color='green', linestyle='--', label='Lower Bound')
plt.axvline(ci_upper, color='green', linestyle='--', label='Upper Bound')
plt.title('Histogram of Sample Data with 95% Confidence Interval')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (92.64, 100.60)

# %% [markdown]
# #### Q.18 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


mu = 0       
sigma = 1    


x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)


pdf = norm.pdf(x, mu, sigma)


plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='blue', lw=2, label=f'N({mu}, {sigma}²)')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# #### Q.19  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson


λ = 4  


x = np.arange(0, 15)


cdf = poisson.cdf(x, mu=λ)


plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='mid', color='green', label=f'Poisson(λ={λ})')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('Number of Events (k)')
plt.ylabel('Cumulative Probability')
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(x)
plt.legend()
plt.show()

# %% [markdown]
# #### Q.20 Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np


a = 2   
b = 10  


sample_size = 10000
samples = np.random.uniform(a, b, sample_size)


empirical_mean = np.mean(samples)

''' the theoretical expected value'''
theoretical_mean = (a + b) / 2


print(f"Empirical Expected Value (Sample Mean): {empirical_mean:.4f}")
print(f"Theoretical Expected Value: {theoretical_mean:.4f}")
# Out:
# Empirical Expected Value (Sample Mean): 6.0023
# Theoretical Expected Value: 6.0000

# %% [markdown]
# #### Q.21 Write a Python program to compare the standard deviations of two datasets and visualize the difference

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=1000)   # Dataset 1: mean=50, std=5, n=1000
data2 = np.random.normal(loc=50, scale=10, size=1000)  # Dataset 2: mean=50, std=10, 


std1 = np.std(data1)
std2 = np.std(data2)

# Print the results
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Plotting histograms
plt.figure(figsize=(10, 6))
plt.hist(data1, bins=30, alpha=0.6, label=f'Dataset 1 (std={std1:.2f})', color='blue')
plt.hist(data2, bins=30, alpha=0.6, label=f'Dataset 2 (std={std2:.2f})', color='orange')
plt.axvline(np.mean(data1), color='blue', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data2), color='orange', linestyle='dashed', linewidth=1)

plt.title('Comparison of Standard')
# Out:
# Standard Deviation of Dataset 1: 4.89
# Standard Deviation of Dataset 2: 9.97
# Text(0.5, 1.0, 'Comparison of Standard')

# %% [markdown]
# #### Q.22 Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=1000)  # mean=100, std=15, n=1000


data_range = np.max(data) - np.min(data)

'''Calculate Interquartile Range (IQR)'''
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1


print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")


plt.figure(figsize=(8, 4))
plt.boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title("Boxplot of Normally Distributed Data")
plt.xlabel("Value")
plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Range: 87.08
# Interquartile Range (IQR): 19.58

# %% [markdown]
# #### Q.23 Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)  # mean=50, std=10


data_reshaped = data.reshape(-1, 1)


scaler = StandardScaler()
normalized_data = scaler.fit_transform(data_reshaped).flatten()


plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Before Z-score Normalization")
plt.xlabel("Value")
plt.ylabel("Frequency")


plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='salmon', edgecolor='black')
plt.title("After Z-score Normalization")
plt.xlabel("Z-score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


print(f"Original Mean: {np.mean(data):.2f}, Std Dev: {np.std(data):.2f}")
print(f"Normalized Mean: {np.mean(normalized_data):.2f}, Std Dev: {np.std(normalized_data):.2f}")
# Out:
# Original Mean: 50.19, Std Dev: 9.79
# Normalized Mean: -0.00, Std Dev: 1.00

# %% [markdown]
# #### Q.24 Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_distribution_stats(size=1000, mean=0, std=1):

    data = np.random.normal(loc=mean, scale=std, size=size)


    data_skewness = skew(data)
    data_kurtosis = kurtosis(data)  


    print(f"Sample Size: {size}")
    print(f"Mean: {np.mean(data):.4f}, Std Dev: {np.std(data):.4f}")
    print(f"Skewness: {data_skewness:.4f} (expected ≈ 0 for normal)")
    print(f"Kurtosis: {data_kurtosis:.4f} (expected ≈ 0 for normal)")

    return data_skewness, data_kurtosis


analyze_distribution_stats()
# Out:
# Sample Size: 1000
# Mean: 0.0058, Std Dev: 0.9830
# Skewness: 0.0612 (expected ≈ 0 for normal)
# Kurtosis: 0.1653 (expected ≈ 0 for normal)
# (0.06115473121061752, 0.16534715876607775)
